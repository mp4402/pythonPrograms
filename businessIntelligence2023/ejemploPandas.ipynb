# %%
import pandas as pd

# %%
df_airports = pd.read_csv('airports.csv')
df_airport_freq = pd.read_csv('airport-frequencies.csv')
df_runways = pd.read_csv('runways.csv')

# %%
df_airports
# Out:
#            id    ident           type                                name  \
# 0        6523      00A       heliport                   Total Rf Heliport
# 1      323361     00AA  small_airport                Aero B Ranch Airport
# 2        6524     00AK  small_airport                        Lowell Field
# 3        6525     00AL  small_airport                        Epps Airpark
# 4        6526     00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...      ...            ...                                 ...
# 74661   46378  ZZ-0001       heliport                     Sealand Helipad
# 74662  307326  ZZ-0002  small_airport           Glorioso Islands Airstrip
# 74663  346788  ZZ-0003  small_airport               Fainting Goat Airport
# 74664  342102     ZZZW         closed              Scandium City Heliport
# 74665  313629     ZZZZ  small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# 1         38.704022    -101.473911        3435.0       NaN          US
# 2         59.947733    -151.692524         450.0       NaN          US
# 3         34.864799     -86.770302         820.0       NaN          US
# 4         35.608700     -91.254898         237.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 74661     51.894444       1.482500          40.0        EU          GB
# 74662    -11.584278      47.296389          11.0        AF          TF
# 74663     32.110587     -97.356312         690.0       NaN          US
# 74664     69.355287    -138.939310           4.0       NaN          CA
# 74665     30.784722     130.270556         338.0        AS          JP
#
#       iso_region         municipality scheduled_service gps_code iata_code  \
# 0          US-PA             Bensalem                no      00A       NaN
# 1          US-KS                Leoti                no     00AA       NaN
# 2          US-AK         Anchor Point                no     00AK       NaN
# 3          US-AL              Harvest                no     00AL       NaN
# 4          US-AR              Newport                no      NaN       NaN
# ...          ...                  ...               ...      ...       ...
# 74661     GB-ENG              Sealand                no      NaN       NaN
# 74662     TF-U-A     Grande Glorieuse                no      NaN       NaN
# 74663      US-TX                 Blum                no     87TX       NaN
# 74664      CA-YT  (Old) Scandium City                no      NaN       NaN
# 74665      JP-46              Mishima                no     RJX7       NaN
#
#       local_code                   home_link  \
# 0            00A                         NaN
# 1           00AA                         NaN
# 2           00AK                         NaN
# 3           00AL                         NaN
# 4            NaN                         NaN
# ...          ...                         ...
# 74661        NaN  http://www.sealandgov.org/
# 74662        NaN                         NaN
# 74663       87TX                         NaN
# 74664        NaN                         NaN
# 74665       RJX7                         NaN
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 74661  https://en.wikipedia.org/wiki/Principality_of_...
# 74662                                                NaN
# 74663                                                NaN
# 74664                                                NaN
# 74665  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                       00AR
# ...                      ...
# 74661   Roughs Tower Helipad
# 74662                    NaN
# 74663                    NaN
# 74664  ZZZW, ZZZW, ZYW, YK96
# 74665   SATSUMA,IWOJIMA,RJX7
#
# [74666 rows x 18 columns]

# %%
airports.head(3)
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
# 1                no     00AA       NaN       00AA       NaN            NaN
# 2                no     00AK       NaN       00AK       NaN            NaN
#
#   keywords
# 0      NaN
# 1      NaN
# 2      NaN

# %%
airports[airports.ident == 'KLAX'].id
# Out:
# 36296    3632
# Name: id, dtype: int64

# %%
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]
# Out:
#            id    ident           type  \
# 1025     7436      0O0  seaplane_base
# 2603     8877     22CA  seaplane_base
# 6556    12298     5CA9  seaplane_base
# 15757   16514      C39  seaplane_base
# 18511   16830     CN20  seaplane_base
# 21197   17157      E20  seaplane_base
# 27328   17613      H77  seaplane_base
# 39137   21444      L11  seaplane_base
# 47130   23479      O06  seaplane_base
# 51954   24384      S74  seaplane_base
# 60707  300312      TWH  seaplane_base
# 65044  342286  US-3338  seaplane_base
#
#                                            name  latitude_deg  longitude_deg  \
# 1025           San Luis Reservoir Seaplane Base     37.058300    -121.125999
# 2603             Commodore Center Seaplane Base     37.878893    -122.512697
# 6556        Konocti  - Clear Lake Seaplane Base     38.977699    -122.718002
# 15757                 Folsom Lake Seaplane Base     38.707199    -121.133003
# 18511             Ferndale Resort Seaplane Base     39.002998    -122.796997
# 21197              Lake Berryessa Seaplane Base     38.550979    -122.227682
# 27328           Bridge Bay Resort Seaplane Base     40.757599    -122.322998
# 39137                Pebbly Beach Seaplane Base     33.338402    -118.311996
# 47130  Lake Oroville Landing Area Seaplane Base     39.566601    -121.468002
# 51954                   Lost Isle Seaplane Base     38.004101    -121.457001
# 60707           Two Harbors Amphibious Terminal     33.432222    -118.508611
# 65044                 Avalon Port Seaplane Base     33.345260    -118.324329
#
#        elevation_ft continent iso_country iso_region municipality  \
# 1025          544.0       NaN          US      US-CA    Los Banos
# 2603            NaN       NaN          US      US-CA  Mill Valley
# 6556         1326.0       NaN          US      US-CA  Kelseyville
# 15757         466.0       NaN          US      US-CA       Folsom
# 18511        1326.0       NaN          US      US-CA  Kelseyville
# 21197         440.0       NaN          US      US-CA         Napa
# 27328        1065.0       NaN          US      US-CA      Redding
# 39137           NaN       NaN          US      US-CA       Avalon
# 47130         900.0       NaN          US      US-CA     Oroville
# 51954           NaN       NaN          US      US-CA     Stockton
# 60707           NaN       NaN          US      US-CA  Two Harbors
# 65044           NaN       NaN          US      US-CA       Avalon
#
#       scheduled_service gps_code iata_code local_code home_link  \
# 1025                 no      0O0       NaN        0O0       NaN
# 2603                 no     22CA       NaN       22CA       NaN
# 6556                 no     5CA9       NaN       5CA9       NaN
# 15757                no      C39       NaN        C39       NaN
# 18511                no     CN20       NaN       CN20       NaN
# 21197                no      NaN       NaN        E20       NaN
# 27328                no      H77       NaN        H77       NaN
# 39137                no     KL11       NaN        L11       NaN
# 47130                no      O06       NaN        O06       NaN
# 51954                no      S74       NaN        S74       NaN
# 60707                no      NaN       TWH        NaN       NaN
# 65044                no      NaN       NaN        NaN       NaN
#
#       wikipedia_link keywords
# 1025             NaN      NaN
# 2603             NaN      NaN
# 6556             NaN      NaN
# 15757            NaN      NaN
# 18511            NaN      NaN
# 21197            NaN      NaN
# 27328            NaN      NaN
# 39137            NaN      NaN
# 47130            NaN      NaN
# 51954            NaN      NaN
# 60707            NaN      NaN
# 65044            NaN      NaN

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 12102  60776         3632          KLAX  UNIC      UNICOM         122.95
# 12101  60775         3632          KLAX   TWR         TWR         119.80
# 12100  60774         3632          KLAX   OPS          AF          37.22
# 12098  60772         3632          KLAX  MISC          CG          34.50
# 12099  60773         3632          KLAX  MISC          CG         898.40
# 12097  60771         3632          KLAX   GND         GND         121.65
# 12096  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 12095  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 12094  60768         3632          KLAX  ATIS        ATIS         133.80
# 12092  60767         3632          KLAX   APP   SOCAL APP          36.07
# 12093  60766         3632          KLAX   APP   SOCAL APP         124.30

# %%
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident      type                             name  \
# 0        6523      00A  heliport                Total Rf Heliport
# 9      322658     00CN  heliport  Kitchen Creek Helibase Heliport
# 15       6535     00GE  heliport                 Caffrey Heliport
# 16       6536     00HI  heliport               Kaupulehu Heliport
# 21       6540     00IN  heliport  St Mary Medical Center Heliport
# ...       ...      ...       ...                              ...
# 74603  351677  ZW-0055  heliport          Elephant Hills Heliport
# 74604  351678  ZW-0056  heliport             Chikopokopo Heliport
# 74605  351679  ZW-0057  heliport                  Masuwe Heliport
# 74607  351689  ZW-0059  heliport                Big Four Heliport
# 74661   46378  ZZ-0001  heliport                  Sealand Helipad
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# 9         32.727374    -116.459742        3350.0       NaN          US
# 15        33.887982     -84.736983         957.0       NaN          US
# 16        19.832881    -155.978347          43.0        OC          US
# 21        41.511398     -87.260597         634.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 74603    -17.911990      25.828020        3054.0        AF          ZW
# 74604    -17.964380      25.809930        3012.0        AF          ZW
# 74605    -17.965880      25.810550        3005.0        AF          ZW
# 74607    -17.913540      25.832350        2986.0        AF          ZW
# 74661     51.894444       1.482500          40.0        EU          GB
#
#       iso_region    municipality scheduled_service gps_code iata_code  \
# 0          US-PA        Bensalem                no      00A       NaN
# 9          US-CA     Pine Valley                no     00CN       NaN
# 15         US-GA           Hiram                no     00GE       NaN
# 16         US-HI     Kailua-Kona                no     00HI       NaN
# 21         US-IN          Hobart                no     00IN       NaN
# ...          ...             ...               ...      ...       ...
# 74603      ZW-MN  Victoria Falls                no      NaN       NaN
# 74604      ZW-MN          Masuwe                no      NaN       NaN
# 74605      ZW-MN          Masuwe                no      NaN       NaN
# 74607      ZW-MN  Victoria Falls                no      NaN       NaN
# 74661     GB-ENG         Sealand                no      NaN       NaN
#
#       local_code                   home_link  \
# 0            00A                         NaN
# 9           00CN                         NaN
# 15          00GE                         NaN
# 16          00HI                         NaN
# 21          00IN                         NaN
# ...          ...                         ...
# 74603        NaN                         NaN
# 74604        NaN                         NaN
# 74605        NaN                         NaN
# 74607        NaN                         NaN
# 74661        NaN  http://www.sealandgov.org/
#
#                                           wikipedia_link              keywords
# 0                                                    NaN                   NaN
# 9                                                    NaN                   NaN
# 15                                                   NaN                   NaN
# 16                                                   NaN                   NaN
# 21                                                   NaN                   NaN
# ...                                                  ...                   ...
# 74603                                                NaN                   NaN
# 74604                                                NaN                   NaN
# 74605                                                NaN                   NaN
# 74607                                                NaN                   NaN
# 74661  https://en.wikipedia.org/wiki/Principality_of_...  Roughs Tower Helipad
#
# [19032 rows x 18 columns]

# %%
airports[~airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident            type                                name  \
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# 5      322127     00AS   small_airport                      Fulton Airport
# ...       ...      ...             ...                                 ...
# 74660   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 74662  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 74663  346788  ZZ-0003   small_airport               Fainting Goat Airport
# 74664  342102     ZZZW          closed              Scandium City Heliport
# 74665  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 1         38.704022    -101.473911        3435.0       NaN          US
# 2         59.947733    -151.692524         450.0       NaN          US
# 3         34.864799     -86.770302         820.0       NaN          US
# 4         35.608700     -91.254898         237.0       NaN          US
# 5         34.942803     -97.818019        1100.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 74660     41.784401     123.496002           NaN        AS          CN
# 74662    -11.584278      47.296389          11.0        AF          TF
# 74663     32.110587     -97.356312         690.0       NaN          US
# 74664     69.355287    -138.939310           4.0       NaN          CA
# 74665     30.784722     130.270556         338.0        AS          JP
#
#       iso_region         municipality scheduled_service gps_code iata_code  \
# 1          US-KS                Leoti                no     00AA       NaN
# 2          US-AK         Anchor Point                no     00AK       NaN
# 3          US-AL              Harvest                no     00AL       NaN
# 4          US-AR              Newport                no      NaN       NaN
# 5          US-OK                 Alex                no     00AS       NaN
# ...          ...                  ...               ...      ...       ...
# 74660      CN-21     Dadong, Shenyang                no     ZYYY       NaN
# 74662     TF-U-A     Grande Glorieuse                no      NaN       NaN
# 74663      US-TX                 Blum                no     87TX       NaN
# 74664      CA-YT  (Old) Scandium City                no      NaN       NaN
# 74665      JP-46              Mishima                no     RJX7       NaN
#
#       local_code home_link                                     wikipedia_link  \
# 1           00AA       NaN                                                NaN
# 2           00AK       NaN                                                NaN
# 3           00AL       NaN                                                NaN
# 4            NaN       NaN                                                NaN
# 5           00AS       NaN                                                NaN
# ...          ...       ...                                                ...
# 74660        NaN       NaN                                                NaN
# 74662        NaN       NaN                                                NaN
# 74663       87TX       NaN                                                NaN
# 74664        NaN       NaN                                                NaN
# 74665       RJX7       NaN  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                       00AR
# 5                        NaN
# ...                      ...
# 74660                    NaN
# 74662                    NaN
# 74663                    NaN
# 74664  ZZZW, ZZZW, ZYW, YK96
# 74665   SATSUMA,IWOJIMA,RJX7
#
# [55634 rows x 18 columns]
